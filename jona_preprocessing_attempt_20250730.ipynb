# %%
# set up libraries
    # We will need the RBCPath type from the rbclib package to load data from the RBC.
from rbclib import RBCPath
    # We'll also want to load some data directly from the filesystem.
from pathlib import Path
    # We'll want to load/process some of the data using pandas and numpy.
import pandas as pd
import numpy as np

# %%
# functions form the given analysis function 
def load_fsdata(participant_id, local_cache_dir=(Path.home() / 'cache')):
    "Loads and returns the dataframe of a PNC participant's FreeSurfer data."
    # from Neurohakademy 2025 organizers

    # Check that the local_cache_dir exists and make it if it doesn't.
    if local_cache_dir is not None:
        local_cache_dir = Path(local_cache_dir)
        local_cache_dir.mkdir(exist_ok=True)
    
    # Make the RBCPath and find the appropriate file:
    pnc_freesurfer_path = RBCPath(
        'rbc://PNC_FreeSurfer/freesurfer',
        # We provide the local_cache_dir to the RBCPath object; all paths made
        # from this object will use the same cache directory.
        local_cache_dir=local_cache_dir)
    participant_path = pnc_freesurfer_path / f'sub-{participant_id}'
    tsv_path = participant_path / f'sub-{participant_id}_regionsurfacestats.tsv'

    # Use pandas to read in the TSV file:
    with tsv_path.open('r') as f:
        data = pd.read_csv(f, sep='\t')

    # Return the loaded data:
    return data

# %%
# My functions 
def flatten_RBC_participant(participant_id):
    "Flatten the data from RBC for a given participant."
    
    # Load Data
    df = load_fsdata(participant_id)
    
    # Summarize Feature Info
    df['feature_info'] = df[['atlas', 'hemisphere', 'StructName']].agg('__'.join, axis=1)
    df = df.drop(columns=['atlas', 'hemisphere', 'StructName'])
    
    # Make a place to store the data
    output_df = pd.DataFrame(columns = ['measure_info', 'value'])
    
    # Iterate through the measures flattening them and adding them to the new df
    allowed_measures = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd', 
                        'Index', 'SegId', 'Mean_wgpct', 'StdDev_wgpct', 'Min_wgpct', 'Max_wgpct', 'Range_wgpct', 'SNR_wgpct', 
                        'Mean_piallgi', 'StdDev_piallgi', 'Min_piallgi', 'Max_piallgi', 'Range_piallgi']
    for measure in allowed_measures:
        temp_df = pd.DataFrame(columns = ['measure_info', 'value'])
        labels = df['feature_info'].apply(lambda x : f'{x}__{measure}')
        values = df[measure]
        temp_df['measure_info'] = labels
        temp_df['value'] = values
        output_df = pd.concat([output_df, temp_df])
    
    return output_df


def make_RBC_data_into_a_table(participant_id_list):
    '''Make a dataframe of all RBC participants in the given list'''

    # Initialize the df with the first participant
    output_flattened_df = flatten_RBC_participant(participant_id_list[0])
    output_flattened_df = output_flattened_df.rename(columns={'value':participant_id_list[0]}).set_index('measure_info').T

    # add in all the other participants
    for participant_id in participant_id_list[1:]:
        temp_df = flatten_RBC_participant(participant_id)
        temp_df = temp_df.rename(columns={'value':participant_id}).set_index('measure_info').T
        output_flattened_df = pd.concat([output_flattened_df, temp_df])
    
    return output_flattened_df

# %%
example_participant_id = 1000393599

# Load Data
example_df = load_fsdata(example_participant_id)

# Remove session id because it is empty
example_df = example_df.drop(columns=['session_id'])

# Summarize Feature Info
example_df['feature_info'] = example_df[['atlas', 'hemisphere', 'StructName']].agg('__'.join, axis=1)
# example_df = example_df.drop(columns=['atlas', 'hemisphere', 'StructName'])

# Make a place to store the data
output_df = pd.DataFrame(columns = ['measure_info', 'value'])

# Iterate through the measures flattening them and adding them to the new df
allowed_measures = ['NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv', 'GausCurv', 'FoldInd', 'CurvInd', 
                    'Index', 'SegId', 'Mean_wgpct', 'StdDev_wgpct', 'Min_wgpct', 'Max_wgpct', 'Range_wgpct', 'SNR_wgpct', 
                    'Mean_piallgi', 'StdDev_piallgi', 'Min_piallgi', 'Max_piallgi', 'Range_piallgi']
for measure in allowed_measures:
    temp_df = pd.DataFrame(columns = ['measure_info', 'value'])
    labels = example_df['feature_info'].apply(lambda x : f'{x}__{measure}')
    values = example_df[measure]
    temp_df['measure_info'] = labels
    temp_df['value'] = values
    output_df = pd.concat([output_df, temp_df])
    
output_df
# Out:
#                                             measure_info   value
# 0      aparc.DKTatlas__lh__caudalanteriorcingulate__N...    1668
# 1       aparc.DKTatlas__lh__caudalmiddlefrontal__NumVert    3308
# 2                    aparc.DKTatlas__lh__cuneus__NumVert    4102
# 3                aparc.DKTatlas__lh__entorhinal__NumVert     737
# 4                  aparc.DKTatlas__lh__fusiform__NumVert    4115
# ...                                                  ...     ...
# 13735  Yeo2011_7Networks_N1000__rh__7Networks_3__Rang...    2.25
# 13736  Yeo2011_7Networks_N1000__rh__7Networks_4__Rang...  3.2703
# 13737  Yeo2011_7Networks_N1000__rh__7Networks_5__Rang...  2.7538
# 13738  Yeo2011_7Networks_N1000__rh__7Networks_6__Rang...   3.055
# 13739  Yeo2011_7Networks_N1000__rh__7Networks_7__Rang...   2.759
#
# [302280 rows x 2 columns]

# %%
example_df
# Out:
#            subject_id                    atlas hemisphere  \
# 0      sub-1000393599           aparc.DKTatlas         lh
# 1      sub-1000393599           aparc.DKTatlas         lh
# 2      sub-1000393599           aparc.DKTatlas         lh
# 3      sub-1000393599           aparc.DKTatlas         lh
# 4      sub-1000393599           aparc.DKTatlas         lh
# ...               ...                      ...        ...
# 13735  sub-1000393599  Yeo2011_7Networks_N1000         rh
# 13736  sub-1000393599  Yeo2011_7Networks_N1000         rh
# 13737  sub-1000393599  Yeo2011_7Networks_N1000         rh
# 13738  sub-1000393599  Yeo2011_7Networks_N1000         rh
# 13739  sub-1000393599  Yeo2011_7Networks_N1000         rh
#
#                     StructName  NumVert  SurfArea  GrayVol  ThickAvg  \
# 0      caudalanteriorcingulate     1668      1121     3493     2.870
# 1          caudalmiddlefrontal     3308      2236     7030     2.882
# 2                       cuneus     4102      2619     5753     2.019
# 3                   entorhinal      737       549     2714     3.655
# 4                     fusiform     4115      2822     8180     2.738
# ...                        ...      ...       ...      ...       ...
# 13735              7Networks_3    14937      9936    27688     2.611
# 13736              7Networks_4    13382      9146    29555     2.909
# 13737              7Networks_5    10558      7677    31072     3.196
# 13738              7Networks_6    20144     13602    41999     2.696
# 13739              7Networks_7    24278     16614    55069     2.878
#
#        ThickStd  MeanCurv  ...  Min_wgpct  Max_wgpct  Range_wgpct  SNR_wgpct  \
# 0         0.588     0.122  ...    -1.8413    42.8855      44.7269     4.4281
# 1         0.537     0.109  ...     7.1531    40.4774      33.3243     5.0341
# 2         0.490     0.125  ...   -13.1617    33.8137      46.9754     3.0343
# 3         0.585     0.144  ...     2.5989    37.5099      34.9110     3.4560
# 4         0.526     0.130  ...    -5.9378    39.6908      45.6286     3.9405
# ...         ...       ...  ...        ...        ...          ...        ...
# 13735     0.492     0.123  ...   -10.8846    39.2314      50.1161     4.1769
# 13736     0.582     0.127  ...   -41.1954    52.2013      93.3967     3.8157
# 13737     0.792     0.143  ...   -22.2837    88.8118     111.0955     3.3020
# 13738     0.641     0.135  ...   -11.6287    43.5814      55.2101     3.6592
# 13739     0.571     0.134  ...   -18.0298    48.6628      66.6926     3.7574
#
#        Mean_piallgi  StdDev_piallgi  Min_piallgi  Max_piallgi  Range_piallgi  \
# 0            1.9877          0.0777       1.8054       2.1455         0.3402
# 1            3.3898          0.2448       2.7003       3.8032         1.1029
# 2            3.2453          0.3093       2.4099       3.5491         1.1392
# 3            2.6710          0.1285       2.4654       2.9647         0.4993
# 4            2.8272          0.1093       2.3304       3.1105         0.7800
# ...             ...             ...          ...          ...            ...
# 13735        3.1173          0.3747       2.4544       4.7044         2.2500
# 13736        3.5262          0.9928       1.8828       5.1531         3.2703
# 13737        2.5300          0.3971       2.0215       4.7753         2.7538
# 13738        3.0563          0.5547       1.8599       4.9149         3.0550
# 13739        3.0117          0.6360       1.9099       4.6689         2.7590
#
#                                       feature_info
# 0      aparc.DKTatlas__lh__caudalanteriorcingulate
# 1          aparc.DKTatlas__lh__caudalmiddlefrontal
# 2                       aparc.DKTatlas__lh__cuneus
# 3                   aparc.DKTatlas__lh__entorhinal
# 4                     aparc.DKTatlas__lh__fusiform
# ...                                            ...
# 13735     Yeo2011_7Networks_N1000__rh__7Networks_3
# 13736     Yeo2011_7Networks_N1000__rh__7Networks_4
# 13737     Yeo2011_7Networks_N1000__rh__7Networks_5
# 13738     Yeo2011_7Networks_N1000__rh__7Networks_6
# 13739     Yeo2011_7Networks_N1000__rh__7Networks_7
#
# [13740 rows x 27 columns]

# %%
participant_id = 1000393599
flatten_RBC_participant(participant_id).rename(columns={'value':participant_id}).set_index('measure_info').T
# Out:
# measure_info aparc.DKTatlas__lh__caudalanteriorcingulate__NumVert  \
# 1000393599                                                 1668
#
# measure_info aparc.DKTatlas__lh__caudalmiddlefrontal__NumVert  \
# 1000393599                                               3308
#
# measure_info aparc.DKTatlas__lh__cuneus__NumVert  \
# 1000393599                                  4102
#
# measure_info aparc.DKTatlas__lh__entorhinal__NumVert  \
# 1000393599                                       737
#
# measure_info aparc.DKTatlas__lh__fusiform__NumVert  \
# 1000393599                                    4115
#
# measure_info aparc.DKTatlas__lh__inferiorparietal__NumVert  \
# 1000393599                                            7381
#
# measure_info aparc.DKTatlas__lh__inferiortemporal__NumVert  \
# 1000393599                                            4828
#
# measure_info aparc.DKTatlas__lh__isthmuscingulate__NumVert  \
# 1000393599                                            1578
#
# measure_info aparc.DKTatlas__lh__lateraloccipital__NumVert  \
# 1000393599                                           10035
#
# measure_info aparc.DKTatlas__lh__lateralorbitofrontal__NumVert  ...  \
# 1000393599                                                4309  ...
#
# measure_info Yeo2011_7Networks_N1000__lh__7Networks_6__Range_piallgi  \
# 1000393599                                               3.3341
#
# measure_info Yeo2011_7Networks_N1000__lh__7Networks_7__Range_piallgi  \
# 1000393599                                               3.4807
#
# measure_info Yeo2011_7Networks_N1000__rh__FreeSurfer_Defined_Medial_Wall__Range_piallgi  \
# 1000393599                                               2.4321
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_1__Range_piallgi  \
# 1000393599                                               1.2908
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_2__Range_piallgi  \
# 1000393599                                               3.3515
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_3__Range_piallgi  \
# 1000393599                                                 2.25
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_4__Range_piallgi  \
# 1000393599                                               3.2703
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_5__Range_piallgi  \
# 1000393599                                               2.7538
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_6__Range_piallgi  \
# 1000393599                                                3.055
#
# measure_info Yeo2011_7Networks_N1000__rh__7Networks_7__Range_piallgi
# 1000393599                                                2.759
#
# [1 rows x 302280 columns]

# %%
# make_RBC_data_into_a_table([1000393599,1317462,11407866])
# Out:
# measure_info aparc.DKTatlas__lh__caudalanteriorcingulate__NumVert  \
# 1000393599                                                 1668
# 1317462                                                    1931
# 11407866                                                   2014
#
# measure_info aparc.DKTatlas__lh__caudalmiddlefrontal__NumVert  \
# 1000393599                                               3308
# 1317462                                                  4304
# 11407866                                                 4213
#
# measure_info aparc.DKTatlas__lh__cuneus__NumVert  \
# 1000393599                                  4102
# 1317462                                     3388
# 11407866                                    3230
#
# measure_info aparc.DKTatlas__lh__entorhinal__NumVert  \
# 1000393599                                       737
# 1317462                                          619
# 11407866                                         787
#
# measure_info aparc.DKTatlas__lh__fusiform__NumVert  \
# 1000393599                                    4115
# 1317462                                       4521
# 11407866                                      4320
#
# measure_info aparc.DKTatlas__lh__inferiorparietal__NumVert  \
# 1000393599                                            7381
# 1317462                                               6401
# 11407866                                              7388
#
# measure_info aparc.DKTatlas__lh__inferiortemporal__NumVert  \
# 1000393599                                            4828
# 1317462                                               5000
# 11407866                                              6058
#
# measure_info aparc.DKTatlas__lh__isthmuscingulate__NumVert  \
# 1000393599                                            1578
# 1317462                                               1747
# 11407866                                              1574
#
# measure_info aparc.DKTatlas__lh__lateraloccipital__NumVert  \
# 1000393599                                           10035
# 1317462                                               8199
# 11407866                                              7431
#
# measure_info aparc.DKTatlas__lh__lateralorbitofrontal__NumVert  ...  \
# 1000393599                                                4309  ...
# 1317462                                                   4887  ...
# 11407866                                                  4829  ...
#
# measure_info Slab__rh__region00878__StdDev_piallgi  \
# 1000393599                                     NaN
# 1317462                                        NaN
# 11407866                                       0.0
#
# measure_info CC200__lh__region00047__Min_piallgi  \
# 1000393599                                   NaN
# 1317462                                      NaN
# 11407866                                  2.4648
#
# measure_info CC400__rh__region00012__Min_piallgi  \
# 1000393599                                   NaN
# 1317462                                      NaN
# 11407866                                  2.4339
#
# measure_info Slab__rh__region00878__Min_piallgi  \
# 1000393599                                  NaN
# 1317462                                     NaN
# 11407866                                 3.1556
#
# measure_info CC200__lh__region00047__Max_piallgi  \
# 1000393599                                   NaN
# 1317462                                      NaN
# 11407866                                  2.4648
#
# measure_info CC400__rh__region00012__Max_piallgi  \
# 1000393599                                   NaN
# 1317462                                      NaN
# 11407866                                  2.4339
#
# measure_info Slab__rh__region00878__Max_piallgi  \
# 1000393599                                  NaN
# 1317462                                     NaN
# 11407866                                 3.1556
#
# measure_info CC200__lh__region00047__Range_piallgi  \
# 1000393599                                     NaN
# 1317462                                        NaN
# 11407866                                       0.0
#
# measure_info CC400__rh__region00012__Range_piallgi  \
# 1000393599                                     NaN
# 1317462                                        NaN
# 11407866                                       0.0
#
# measure_info Slab__rh__region00878__Range_piallgi
# 1000393599                                    NaN
# 1317462                                       NaN
# 11407866                                      0.0
#
# [3 rows x 302434 columns]

# %%
# example_df.columns

# %%
example_df.isna().sum(axis=0)
# Out:
# subject_id        0
# atlas             0
# hemisphere        0
# StructName        0
# NumVert           0
# SurfArea          0
# GrayVol           0
# ThickAvg          0
# ThickStd          0
# MeanCurv          0
# GausCurv          0
# FoldInd           0
# CurvInd           0
# Index             0
# SegId             0
# Mean_wgpct        0
# StdDev_wgpct      0
# Min_wgpct         0
# Max_wgpct         0
# Range_wgpct       0
# SNR_wgpct         0
# Mean_piallgi      0
# StdDev_piallgi    0
# Min_piallgi       0
# Max_piallgi       0
# Range_piallgi     0
# feature_info      0
# dtype: int64

# %%
# example_df['StructName'].tolist()
# example_df['hemisphere'].value_counts()

# %%
example_df['StructName'].value_counts().value_counts()
# Out:
# count
# 1     1535
# 2      619
# 3      322
# 4      259
# 5      208
# 9      203
# 8      198
# 7      198
# 10     196
# 6      188
# 40       1
# Name: count, dtype: int64

# %%
count_data = example_df['StructName'].value_counts()
count_data[count_data == 40]
# Out:
# StructName
# Background+FreeSurfer_Defined_Medial_Wall    40
# Name: count, dtype: int64

# %%
count_data = example_df['StructName'].value_counts()
count_data[count_data == 4]
# Out:
# StructName
# 7Networks_LH_Default_Temp_13    4
# inferiortemporal                4
# inferiorparietal                4
# 7Networks_RH_SomMot_63          4
# 17Networks_LH_ContA_PFClv_3     4
#                                ..
# cuneus                          4
# caudalmiddlefrontal             4
# caudalanteriorcingulate         4
# medialorbitofrontal             4
# middletemporal                  4
# Name: count, Length: 259, dtype: int64

# %%
count_data = example_df[['StructName','atlas']].value_counts()
count_data.value_counts()
# Out:
# count
# 1    13034
# 2      353
# Name: count, dtype: int64

# %%
count_data[count_data == 2]
# Out:
# StructName             atlas
# S_central              aparc.a2009s                2
# S_cingul-Marginalis    aparc.a2009s                2
# S_circular_insula_ant  aparc.a2009s                2
# S_circular_insula_inf  aparc.a2009s                2
# S_circular_insula_sup  aparc.a2009s                2
#                                                   ..
# Lat_Fis-ant-Vertical   aparc.a2009s                2
# region00109            CC400                       2
# 17Networks_3           Yeo2011_17Networks_N1000    2
# 17Networks_2           Yeo2011_17Networks_N1000    2
# 17Networks_16          Yeo2011_17Networks_N1000    2
# Name: count, Length: 353, dtype: int64

# %%
example_df['atlas'].value_counts()
# Out:
# atlas
# Schaefer2018_1000Parcels_7Networks_order     1002
# Schaefer2018_1000Parcels_17Networks_order    1002
# Schaefer2018_900Parcels_17Networks_order      902
# Schaefer2018_900Parcels_7Networks_order       902
# Schaefer2018_800Parcels_7Networks_order       802
# Schaefer2018_800Parcels_17Networks_order      802
# Schaefer2018_700Parcels_7Networks_order       702
# Schaefer2018_700Parcels_17Networks_order      702
# Slab                                          693
# Schaefer2018_600Parcels_7Networks_order       602
# Schaefer2018_600Parcels_17Networks_order      602
# Schaefer2018_500Parcels_7Networks_order       502
# Schaefer2018_500Parcels_17Networks_order      502
# Schaefer2018_400Parcels_7Networks_order       402
# Schaefer2018_400Parcels_17Networks_order      402
# CC400                                         376
# glasser                                       362
# gordon333dil                                  335
# Schaefer2018_300Parcels_17Networks_order      302
# Schaefer2018_300Parcels_7Networks_order       302
# CC200                                         203
# Schaefer2018_200Parcels_7Networks_order       202
# Schaefer2018_200Parcels_17Networks_order      202
# aparc.a2009s                                  148
# Schaefer2018_100Parcels_17Networks_order      102
# Schaefer2018_100Parcels_7Networks_order       102
# AAL                                            99
# HOCPATh25                                      95
# Juelich                                        94
# PALS_B12_Brodmann                              85
# aparc                                          68
# aparc.DKTatlas                                 62
# Yeo2011_17Networks_N1000                       36
# BA_exvivo                                      28
# Yeo2011_7Networks_N1000                        16
# Name: count, dtype: int64

# %%
example_df[example_df['atlas'] == 'Yeo2011_17Networks_N1000']
# Out:
#            subject_id                     atlas hemisphere  \
# 13688  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13689  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13690  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13691  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13692  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13693  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13694  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13695  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13696  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13697  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13698  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13699  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13700  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13701  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13702  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13703  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13704  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13705  sub-1000393599  Yeo2011_17Networks_N1000         lh
# 13706  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13707  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13708  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13709  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13710  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13711  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13712  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13713  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13714  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13715  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13716  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13717  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13718  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13719  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13720  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13721  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13722  sub-1000393599  Yeo2011_17Networks_N1000         rh
# 13723  sub-1000393599  Yeo2011_17Networks_N1000         rh
#
#                            StructName  NumVert  SurfArea  GrayVol  ThickAvg  \
# 13688  FreeSurfer_Defined_Medial_Wall     9543      6258     2751     0.885
# 13689                    17Networks_1    13623      8672    19547     2.116
# 13690                    17Networks_2    10745      7056    14383     1.983
# 13691                    17Networks_3    10904      7120    17942     2.320
# 13692                    17Networks_4     9490      6237    17974     2.685
# 13693                    17Networks_5     7747      5161    13358     2.447
# 13694                    17Networks_6     6609      4413    12045     2.557
# 13695                    17Networks_7     7691      5191    16432     2.913
# 13696                    17Networks_8     5840      3869    12818     2.892
# 13697                    17Networks_9     5627      4035    15647     3.081
# 13698                   17Networks_10     4920      3451    12111     2.915
# 13699                   17Networks_11     2683      1824     4740     2.413
# 13700                   17Networks_12     7872      5301    14818     2.670
# 13701                   17Networks_13     6494      4364    14389     2.823
# 13702                   17Networks_14     4153      2814    10391     3.099
# 13703                   17Networks_15     3203      2108     6325     2.808
# 13704                   17Networks_16    11371      7824    25756     2.848
# 13705                   17Networks_17    14738      9936    36617     3.052
# 13706  FreeSurfer_Defined_Medial_Wall     8593      5779     1847     0.799
# 13707                    17Networks_1    14525      9272    22089     2.223
# 13708                    17Networks_2    10776      6892    14729     2.085
# 13709                    17Networks_3    10539      7112    18541     2.381
# 13710                    17Networks_4     8593      5666    16967     2.741
# 13711                    17Networks_5     9674      6398    17502     2.584
# 13712                    17Networks_6     6790      4547    12911     2.628
# 13713                    17Networks_7     8823      5990    18802     2.890
# 13714                    17Networks_8     7556      5210    17272     2.873
# 13715                    17Networks_9     5542      4111    17917     3.320
# 13716                   17Networks_10     4830      3464    12472     2.978
# 13717                   17Networks_11     3081      2080     5606     2.462
# 13718                   17Networks_12     7026      4747    13184     2.632
# 13719                   17Networks_13    10974      7384    24717     2.787
# 13720                   17Networks_14     4567      3131     9863     2.939
# 13721                   17Networks_15     2937      1952     6194     2.927
# 13722                   17Networks_16    12300      8326    26717     2.799
# 13723                   17Networks_17     6213      4309    15830     3.047
#
#        ThickStd  MeanCurv  ...  Min_wgpct  Max_wgpct  Range_wgpct  SNR_wgpct  \
# 13688     1.294     0.091  ...   -60.4127    96.6036     157.0164     0.3895
# 13689     0.646     0.139  ...    -9.0185    48.8780      57.8965     2.9595
# 13690     0.578     0.132  ...   -51.1054    62.3168     113.4222     2.4443
# 13691     0.635     0.118  ...    -7.6208    41.5867      49.2075     2.9989
# 13692     0.588     0.120  ...   -23.3178    39.6753      62.9930     3.3327
# 13693     0.487     0.124  ...    -9.4500    40.4434      49.8934     3.6261
# 13694     0.476     0.123  ...   -13.0442    45.1652      58.2094     4.0900
# 13695     0.641     0.122  ...   -30.7357    43.1987      73.9344     3.5963
# 13696     0.629     0.122  ...   -16.3872    41.3838      57.7710     3.7506
# 13697     0.746     0.139  ...   -25.1028    63.3100      88.4128     2.7455
# 13698     0.656     0.155  ...   -22.3623    94.4850     116.8473     2.9550
# 13699     0.590     0.124  ...    -0.3665    52.5866      52.9531     3.9095
# 13700     0.503     0.125  ...   -17.4153    42.5791      59.9944     4.2400
# 13701     0.609     0.129  ...   -18.6509    46.1711      64.8220     4.1231
# 13702     0.641     0.124  ...    -4.4728    37.6633      42.1361     3.9994
# 13703     0.639     0.123  ...   -14.3769    39.6908      54.0676     3.6826
# 13704     0.515     0.136  ...   -15.2786    47.1195      62.3981     3.8028
# 13705     0.627     0.131  ...   -20.1757    46.1139      66.2895     3.8308
# 13706     1.234     0.088  ...   -64.7728    88.4048     153.1776     0.3304
# 13707     0.710     0.133  ...   -24.0935    46.5221      70.6156     2.9353
# 13708     0.567     0.126  ...   -11.1656    33.8269      44.9925     2.6229
# 13709     0.653     0.126  ...   -16.6175    43.0371      59.6546     3.0167
# 13710     0.629     0.126  ...   -19.5460    38.8426      58.3887     3.6740
# 13711     0.454     0.120  ...    -6.1429    36.6875      42.8304     4.0210
# 13712     0.490     0.127  ...    -5.9331    46.3897      52.3228     4.6958
# 13713     0.572     0.123  ...   -41.1954    52.2013      93.3967     3.7675
# 13714     0.657     0.135  ...   -25.0201    41.8413      66.8615     3.6751
# 13715     0.838     0.140  ...   -13.1574    52.1851      65.3425     3.7023
# 13716     0.666     0.149  ...   -22.2837    88.8118     111.0955     2.9816
# 13717     0.678     0.132  ...    -3.2509    45.9419      49.1928     3.6155
# 13718     0.591     0.128  ...   -10.8846    37.5763      48.4609     4.0642
# 13719     0.627     0.139  ...   -11.6287    43.5814      55.2101     3.5501
# 13720     0.493     0.117  ...    -0.0056    41.1514      41.1570     4.6967
# 13721     0.600     0.134  ...    -1.2928    38.4241      39.7170     3.7074
# 13722     0.557     0.136  ...   -18.0298    48.6628      66.6926     3.7967
# 13723     0.587     0.135  ...   -10.6917    46.8868      57.5785     3.7390
#
#        Mean_piallgi  StdDev_piallgi  Min_piallgi  Max_piallgi  Range_piallgi  \
# 13688        2.4947          0.4153       1.6581       4.1339         2.4758
# 13689        2.8081          0.2518       2.3391       3.5635         1.2245
# 13690        3.1184          0.2792       2.4128       3.5491         1.1363
# 13691        2.9659          0.5278       2.0566       4.8390         2.7824
# 13692        4.6257          0.5825       3.5515       5.5729         2.0214
# 13693        3.2079          0.2347       2.7501       3.6836         0.9335
# 13694        3.3344          0.3585       2.3235       4.0727         1.7492
# 13695        3.7517          1.3434       1.8915       5.5585         3.6670
# 13696        3.1185          0.9323       1.8147       5.2156         3.4009
# 13697        2.8458          0.5489       2.3255       5.1985         2.8730
# 13698        2.3100          0.2395       2.0074       3.6934         1.6860
# 13699        2.8793          0.5000       1.8330       3.5960         1.7630
# 13700        3.3929          0.4680       1.7985       5.0848         3.2863
# 13701        2.9979          0.4564       1.8266       4.0961         2.2695
# 13702        3.9863          0.5563       2.0857       5.4838         3.3982
# 13703        3.1695          0.2325       2.7304       3.5673         0.8369
# 13704        2.6929          0.4864       1.9077       4.2636         2.3559
# 13705        3.3786          0.8475       1.9707       5.1514         3.1807
# 13706        2.5689          0.3213       1.7581       4.1902         2.4321
# 13707        2.7356          0.1908       2.4050       3.4446         1.0396
# 13708        3.1654          0.2842       2.4690       3.6958         1.2268
# 13709        2.8701          0.4859       2.0281       4.4013         2.3732
# 13710        4.4170          0.5205       3.4579       5.3449         1.8870
# 13711        2.9887          0.2568       2.4703       4.0277         1.5575
# 13712        3.2265          0.3940       2.4544       4.3427         1.8884
# 13713        3.5483          1.0819       1.8841       5.1634         3.2793
# 13714        3.1198          0.7869       1.8599       4.9149         3.0550
# 13715        2.6030          0.3831       2.1595       4.7753         2.6158
# 13716        2.3478          0.1608       2.0215       3.0766         1.0551
# 13717        2.8356          0.3634       1.9097       3.6357         1.7260
# 13718        3.3690          0.5040       1.8615       4.8254         2.9639
# 13719        2.9785          0.4843       1.9992       4.7987         2.7994
# 13720        3.9603          0.2170       3.1101       5.0019         1.8918
# 13721        3.1820          0.3201       2.6648       3.6841         1.0194
# 13722        2.8508          0.5608       1.9347       4.1872         2.2525
# 13723        3.0053          0.7030       2.0440       4.7755         2.7315
#
#                                             feature_info
# 13688  Yeo2011_17Networks_N1000__lh__FreeSurfer_Defin...
# 13689         Yeo2011_17Networks_N1000__lh__17Networks_1
# 13690         Yeo2011_17Networks_N1000__lh__17Networks_2
# 13691         Yeo2011_17Networks_N1000__lh__17Networks_3
# 13692         Yeo2011_17Networks_N1000__lh__17Networks_4
# 13693         Yeo2011_17Networks_N1000__lh__17Networks_5
# 13694         Yeo2011_17Networks_N1000__lh__17Networks_6
# 13695         Yeo2011_17Networks_N1000__lh__17Networks_7
# 13696         Yeo2011_17Networks_N1000__lh__17Networks_8
# 13697         Yeo2011_17Networks_N1000__lh__17Networks_9
# 13698        Yeo2011_17Networks_N1000__lh__17Networks_10
# 13699        Yeo2011_17Networks_N1000__lh__17Networks_11
# 13700        Yeo2011_17Networks_N1000__lh__17Networks_12
# 13701        Yeo2011_17Networks_N1000__lh__17Networks_13
# 13702        Yeo2011_17Networks_N1000__lh__17Networks_14
# 13703        Yeo2011_17Networks_N1000__lh__17Networks_15
# 13704        Yeo2011_17Networks_N1000__lh__17Networks_16
# 13705        Yeo2011_17Networks_N1000__lh__17Networks_17
# 13706  Yeo2011_17Networks_N1000__rh__FreeSurfer_Defin...
# 13707         Yeo2011_17Networks_N1000__rh__17Networks_1
# 13708         Yeo2011_17Networks_N1000__rh__17Networks_2
# 13709         Yeo2011_17Networks_N1000__rh__17Networks_3
# 13710         Yeo2011_17Networks_N1000__rh__17Networks_4
# 13711         Yeo2011_17Networks_N1000__rh__17Networks_5
# 13712         Yeo2011_17Networks_N1000__rh__17Networks_6
# 13713         Yeo2011_17Networks_N1000__rh__17Networks_7
# 13714         Yeo2011_17Networks_N1000__rh__17Networks_8
# 13715         Yeo2011_17Networks_N1000__rh__17Networks_9
# 13716        Yeo2011_17Networks_N1000__rh__17Networks_10
# 13717        Yeo2011_17Networks_N1000__rh__17Networks_11
# 13718        Yeo2011_17Networks_N1000__rh__17Networks_12
# 13719        Yeo2011_17Networks_N1000__rh__17Networks_13
# 13720        Yeo2011_17Networks_N1000__rh__17Networks_14
# 13721        Yeo2011_17Networks_N1000__rh__17Networks_15
# 13722        Yeo2011_17Networks_N1000__rh__17Networks_16
# 13723        Yeo2011_17Networks_N1000__rh__17Networks_17
#
# [36 rows x 27 columns]

# %%
data = load_fsdata(1000393599)
data
# Out:
#            subject_id  session_id                    atlas hemisphere  \
# 0      sub-1000393599         NaN           aparc.DKTatlas         lh
# 1      sub-1000393599         NaN           aparc.DKTatlas         lh
# 2      sub-1000393599         NaN           aparc.DKTatlas         lh
# 3      sub-1000393599         NaN           aparc.DKTatlas         lh
# 4      sub-1000393599         NaN           aparc.DKTatlas         lh
# ...               ...         ...                      ...        ...
# 13735  sub-1000393599         NaN  Yeo2011_7Networks_N1000         rh
# 13736  sub-1000393599         NaN  Yeo2011_7Networks_N1000         rh
# 13737  sub-1000393599         NaN  Yeo2011_7Networks_N1000         rh
# 13738  sub-1000393599         NaN  Yeo2011_7Networks_N1000         rh
# 13739  sub-1000393599         NaN  Yeo2011_7Networks_N1000         rh
#
#                     StructName  NumVert  SurfArea  GrayVol  ThickAvg  \
# 0      caudalanteriorcingulate     1668      1121     3493     2.870
# 1          caudalmiddlefrontal     3308      2236     7030     2.882
# 2                       cuneus     4102      2619     5753     2.019
# 3                   entorhinal      737       549     2714     3.655
# 4                     fusiform     4115      2822     8180     2.738
# ...                        ...      ...       ...      ...       ...
# 13735              7Networks_3    14937      9936    27688     2.611
# 13736              7Networks_4    13382      9146    29555     2.909
# 13737              7Networks_5    10558      7677    31072     3.196
# 13738              7Networks_6    20144     13602    41999     2.696
# 13739              7Networks_7    24278     16614    55069     2.878
#
#        ThickStd  ...  StdDev_wgpct  Min_wgpct  Max_wgpct  Range_wgpct  \
# 0         0.588  ...        5.8371    -1.8413    42.8855      44.7269
# 1         0.537  ...        4.6666     7.1531    40.4774      33.3243
# 2         0.490  ...        5.2623   -13.1617    33.8137      46.9754
# 3         0.585  ...        6.0438     2.5989    37.5099      34.9110
# 4         0.526  ...        5.2854    -5.9378    39.6908      45.6286
# ...         ...  ...           ...        ...        ...          ...
# 13735     0.492  ...        5.0774   -10.8846    39.2314      50.1161
# 13736     0.582  ...        5.8317   -41.1954    52.2013      93.3967
# 13737     0.792  ...        7.1063   -22.2837    88.8118     111.0955
# 13738     0.641  ...        6.0781   -11.6287    43.5814      55.2101
# 13739     0.571  ...        6.1819   -18.0298    48.6628      66.6926
#
#        SNR_wgpct  Mean_piallgi  StdDev_piallgi  Min_piallgi  Max_piallgi  \
# 0         4.4281        1.9877          0.0777       1.8054       2.1455
# 1         5.0341        3.3898          0.2448       2.7003       3.8032
# 2         3.0343        3.2453          0.3093       2.4099       3.5491
# 3         3.4560        2.6710          0.1285       2.4654       2.9647
# 4         3.9405        2.8272          0.1093       2.3304       3.1105
# ...          ...           ...             ...          ...          ...
# 13735     4.1769        3.1173          0.3747       2.4544       4.7044
# 13736     3.8157        3.5262          0.9928       1.8828       5.1531
# 13737     3.3020        2.5300          0.3971       2.0215       4.7753
# 13738     3.6592        3.0563          0.5547       1.8599       4.9149
# 13739     3.7574        3.0117          0.6360       1.9099       4.6689
#
#        Range_piallgi
# 0             0.3402
# 1             1.1029
# 2             1.1392
# 3             0.4993
# 4             0.7800
# ...              ...
# 13735         2.2500
# 13736         3.2703
# 13737         2.7538
# 13738         3.0550
# 13739         2.7590
#
# [13740 rows x 27 columns]

# %%
set([struct for struct in data['StructName'] if "cingulate" in struct])
# Out:
# {'Paracingulate_Gyrus',
#  'caudalanteriorcingulate',
#  'isthmuscingulate',
#  'posteriorcingulate',
#  'rostralanteriorcingulate'}

# %%
set([struct for struct in data['StructName'] if "insula" in struct])
# Out:
# {'G_insular_short',
#  'S_circular_insula_ant',
#  'S_circular_insula_inf',
#  'S_circular_insula_sup',
#  'insula'}

# %%
structs = ['Paracingulate_Gyrus', 'caudalanteriorcingulate', 'isthmuscingulate', 'posteriorcingulate', 
 'rostralanteriorcingulate', 'G_insular_short', 'S_circular_insula_ant', 'S_circular_insula_inf',
 'S_circular_insula_sup', 'insula']

# %%
reduced_df = data[data['StructName'].isin(structs) & (data['atlas'] == 'aparc.DKTatlas')]
reduced_df
# Out:
#         subject_id  session_id           atlas hemisphere  \
# 0   sub-1000393599         NaN  aparc.DKTatlas         lh
# 7   sub-1000393599         NaN  aparc.DKTatlas         lh
# 20  sub-1000393599         NaN  aparc.DKTatlas         lh
# 23  sub-1000393599         NaN  aparc.DKTatlas         lh
# 30  sub-1000393599         NaN  aparc.DKTatlas         lh
# 31  sub-1000393599         NaN  aparc.DKTatlas         rh
# 38  sub-1000393599         NaN  aparc.DKTatlas         rh
# 51  sub-1000393599         NaN  aparc.DKTatlas         rh
# 54  sub-1000393599         NaN  aparc.DKTatlas         rh
# 61  sub-1000393599         NaN  aparc.DKTatlas         rh
#
#                   StructName  NumVert  SurfArea  GrayVol  ThickAvg  ThickStd  \
# 0    caudalanteriorcingulate     1668      1121     3493     2.870     0.588
# 7           isthmuscingulate     1578      1002     2545     2.371     0.719
# 20        posteriorcingulate     2055      1415     4181     2.787     0.581
# 23  rostralanteriorcingulate     1746      1153     3980     3.151     0.668
# 30                    insula     2808      1852     6365     3.252     0.735
# 31   caudalanteriorcingulate      955       607     2092     2.914     0.668
# 38          isthmuscingulate     1487       945     2586     2.403     0.749
# 51        posteriorcingulate     1998      1363     4428     2.909     0.541
# 54  rostralanteriorcingulate     1089       718     2239     2.882     0.802
# 61                    insula     2915      1976     6407     3.238     0.764
#
#     ...  StdDev_wgpct  Min_wgpct  Max_wgpct  Range_wgpct  SNR_wgpct  \
# 0   ...        5.8371    -1.8413    42.8855      44.7269     4.4281
# 7   ...        5.6952    -1.1202    35.8699      36.9901     3.6037
# 20  ...        5.5395   -10.9196    38.8334      49.7531     4.2065
# 23  ...        9.1462   -21.5070    43.9405      65.4476     2.3592
# 30  ...        6.2826   -30.7357    41.3282      72.0640     3.1291
# 31  ...        7.6800   -15.6167    42.7173      58.3340     3.2970
# 38  ...        5.6479    -3.2394    38.5529      41.7923     3.5000
# 51  ...        5.3520   -13.4724    37.7767      51.2491     4.3435
# 54  ...       11.2468   -59.3030    47.1047     106.4077     2.0924
# 61  ...        6.1994   -39.9900    52.2013      92.1913     3.2563
#
#     Mean_piallgi  StdDev_piallgi  Min_piallgi  Max_piallgi  Range_piallgi
# 0         1.9877          0.0777       1.8054       2.1455         0.3402
# 7         2.7171          0.2753       2.1326       3.2785         1.1458
# 20        2.2051          0.2040       1.8125       2.6093         0.7968
# 23        2.1292          0.0596       1.8578       2.2526         0.3948
# 30        5.0003          0.4752       2.5244       5.5729         3.0485
# 31        1.9822          0.0639       1.8644       2.1991         0.3347
# 38        3.0053          0.2426       2.4277       3.4584         1.0307
# 51        2.2745          0.2501       1.8760       2.9094         1.0334
# 54        2.2475          0.0629       2.0572       2.3975         0.3403
# 61        4.6736          0.5146       2.5010       5.3449         2.8439
#
# [10 rows x 27 columns]

# %%
# reduced_df['atlas'].value_counts()

# %%
reduced_df['feature_info'] = reduced_df[['atlas', 'hemisphere', 'StructName']].agg('__'.join, axis=1)
# Out:
# /tmp/ipykernel_128/37269277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['feature_info'] = reduced_df[['atlas', 'hemisphere', 'StructName']].agg('__'.join, axis=1)

# %%
reduced_df.columns
# Out:
# Index(['subject_id', 'session_id', 'atlas', 'hemisphere', 'StructName',
#        'NumVert', 'SurfArea', 'GrayVol', 'ThickAvg', 'ThickStd', 'MeanCurv',
#        'GausCurv', 'FoldInd', 'CurvInd', 'Index', 'SegId', 'Mean_wgpct',
#        'StdDev_wgpct', 'Min_wgpct', 'Max_wgpct', 'Range_wgpct', 'SNR_wgpct',
#        'Mean_piallgi', 'StdDev_piallgi', 'Min_piallgi', 'Max_piallgi',
#        'Range_piallgi', 'feature_info'],
#       dtype='object')

# %%
reduced_df[['feature_info','SurfArea', 'GrayVol']]
# Out:
#                                     feature_info  SurfArea  GrayVol
# 0    aparc.DKTatlas__lh__caudalanteriorcingulate      1121     3493
# 7           aparc.DKTatlas__lh__isthmuscingulate      1002     2545
# 20        aparc.DKTatlas__lh__posteriorcingulate      1415     4181
# 23  aparc.DKTatlas__lh__rostralanteriorcingulate      1153     3980
# 30                    aparc.DKTatlas__lh__insula      1852     6365
# 31   aparc.DKTatlas__rh__caudalanteriorcingulate       607     2092
# 38          aparc.DKTatlas__rh__isthmuscingulate       945     2586
# 51        aparc.DKTatlas__rh__posteriorcingulate      1363     4428
# 54  aparc.DKTatlas__rh__rostralanteriorcingulate       718     2239
# 61                    aparc.DKTatlas__rh__insula      1976     6407

# %%
names = reduced_df['feature_info'].apply(lambda x : x+'SurfArea').tolist() + reduced_df['feature_info'].apply(lambda x : x+'GrayVol').tolist()
names
# Out:
# ['aparc.DKTatlas__lh__caudalanteriorcingulateSurfArea',
#  'aparc.DKTatlas__lh__isthmuscingulateSurfArea',
#  'aparc.DKTatlas__lh__posteriorcingulateSurfArea',
#  'aparc.DKTatlas__lh__rostralanteriorcingulateSurfArea',
#  'aparc.DKTatlas__lh__insulaSurfArea',
#  'aparc.DKTatlas__rh__caudalanteriorcingulateSurfArea',
#  'aparc.DKTatlas__rh__isthmuscingulateSurfArea',
#  'aparc.DKTatlas__rh__posteriorcingulateSurfArea',
#  'aparc.DKTatlas__rh__rostralanteriorcingulateSurfArea',
#  'aparc.DKTatlas__rh__insulaSurfArea',
#  'aparc.DKTatlas__lh__caudalanteriorcingulateGrayVol',
#  'aparc.DKTatlas__lh__isthmuscingulateGrayVol',
#  'aparc.DKTatlas__lh__posteriorcingulateGrayVol',
#  'aparc.DKTatlas__lh__rostralanteriorcingulateGrayVol',
#  'aparc.DKTatlas__lh__insulaGrayVol',
#  'aparc.DKTatlas__rh__caudalanteriorcingulateGrayVol',
#  'aparc.DKTatlas__rh__isthmuscingulateGrayVol',
#  'aparc.DKTatlas__rh__posteriorcingulateGrayVol',
#  'aparc.DKTatlas__rh__rostralanteriorcingulateGrayVol',
#  'aparc.DKTatlas__rh__insulaGrayVol']

# %%
def load_ba1_surfarea(participant_id):
    """Loads and returns the bilateral Brodmann Area 1 surface area for a PNC
    study participant.
    """
    # First, load the subject's FreeSurfer dataframe:
    data = load_fsdata(participant_id)
    # Next, find the relevant rows:
    row_mask = (data['StructName'] == 'Brodmann.1')
    # Then extract and sum the surface areas:
    ba1_surfareas = data.loc[row_mask, 'SurfArea']
    ba1_surfarea = sum(ba1_surfareas)
    # And return this value:
    return ba1_surfarea

# %%
load_ba1_surfarea(1000393599)
# Out:
# 3290

# %%
def load_data_of_intrest(participant_id,structs,measures):
    """Loads and returns the bilateral Brodmann Area 1 surface area for a PNC
    study participant.
    """
    # First, load the subject's FreeSurfer dataframe:
    data = load_fsdata(participant_id)
    data = data[data['atlas'] == 'aparc.DKTatlas'] # get down to just one atlas
    # Next, find the relevant rows:
    row_mask = (data['StructName'].isin(structs))
    # print(sum(row_mask))
    # Then extract the data:
    output_data = data.loc[row_mask, measures].values.flatten().tolist()
    # And return this value:
    return output_data

# %%
structs = ['Paracingulate_Gyrus', 'caudalanteriorcingulate', 'isthmuscingulate', 'posteriorcingulate', 
     'rostralanteriorcingulate', 'G_insular_short', 'S_circular_insula_ant', 'S_circular_insula_inf',
     'S_circular_insula_sup', 'insula']
measures = ['SurfArea','GrayVol']
load_data_of_intrest(1000393599,structs,measures)
# Out:
# [1121,
#  3493,
#  1002,
#  2545,
#  1415,
#  4181,
#  1153,
#  3980,
#  1852,
#  6365,
#  607,
#  2092,
#  945,
#  2586,
#  1363,
#  4428,
#  718,
#  2239,
#  1976,
#  6407]

# %%
# Participant meta-data is generally located in the BIDS repository for each
# study:
rbcdata_path = Path('/home/jovyan/shared/data/RBC')
train_filepath = rbcdata_path / 'train_participants.tsv'
test_filepath = rbcdata_path / 'test_participants.tsv'

# Load the PNC participants TSV files...
with train_filepath.open('r') as f:
    train_data = pd.read_csv(f, sep='\t')
with test_filepath.open('r') as f:
    test_data = pd.read_csv(f, sep='\t')

# We can also concatenate the two datasets into a single dataset of all
# study participants:
all_data = pd.concat([train_data, test_data])

# Display the full dataframe:
all_data
# Out:
#      participant_id study study_site session_id  wave        age     sex  \
# 0        1000393599   PNC       PNC1       PNC1     1  15.583333    Male
# 1        1001970838   PNC       PNC1       PNC1     1  17.833333    Male
# 2        1007995238   PNC       PNC1       PNC1     1  13.750000  Female
# 3        1011497669   PNC       PNC1       PNC1     1  16.666667    Male
# 4        1017092387   PNC       PNC1       PNC1     1  18.666667  Female
# ..              ...   ...        ...        ...   ...        ...     ...
# 529       969649154   PNC       PNC1       PNC1     1  12.333333    Male
# 530       970890500   PNC       PNC1       PNC1     1  18.166667  Female
# 531       975856179   PNC       PNC1       PNC1     1  11.000000    Male
# 532       984757368   PNC       PNC1       PNC1     1  13.416667    Male
# 533       987544292   PNC       PNC1       PNC1     1  18.416667  Female
#
#       race               ethnicity    bmi handedness participant_education  \
# 0    Black  not Hispanic or Latino  22.15      Right             9th Grade
# 1    Other      Hispanic or Latino  23.98      Right            11th Grade
# 2    Other  not Hispanic or Latino  23.77      Right             6th Grade
# 3    White  not Hispanic or Latino  29.68      Right             9th Grade
# 4    Black  not Hispanic or Latino  23.24      Right            11th Grade
# ..     ...                     ...    ...        ...                   ...
# 529  White  not Hispanic or Latino  17.38      Right             5th Grade
# 530  White  not Hispanic or Latino  30.89      Right            11th Grade
# 531  White  not Hispanic or Latino  15.67      Right             4th Grade
# 532  Black  not Hispanic or Latino  16.66      Right             5th Grade
# 533  White  not Hispanic or Latino    NaN      Right            11th Grade
#
#      parent_1_education  parent_2_education  p_factor  \
# 0      Complete primary  Complete secondary  0.589907
# 1     Complete tertiary   Complete tertiary -0.659061
# 2     Complete tertiary    Complete primary -1.608375
# 3     Complete tertiary   Complete tertiary -1.233807
# 4      Complete primary    Complete primary -0.923100
# ..                  ...                 ...       ...
# 529   Complete tertiary  Complete secondary       NaN
# 530  Complete secondary  Complete secondary       NaN
# 531    Complete primary  Complete secondary       NaN
# 532    Complete primary                 NaN       NaN
# 533  Complete secondary    Complete primary       NaN
#
#      internalizing_mcelroy_harmonized_all_samples  \
# 0                                       -0.449373
# 1                                        0.531072
# 2                                       -0.744118
# 3                                       -0.896835
# 4                                       -0.313455
# ..                                            ...
# 529                                     -0.148520
# 530                                      0.993806
# 531                                     -1.026645
# 532                                      0.360029
# 533                                      0.399735
#
#      externalizing_mcelroy_harmonized_all_samples  \
# 0                                       -0.630780
# 1                                        0.392751
# 2                                       -0.314187
# 3                                       -0.449099
# 4                                        2.204168
# ..                                            ...
# 529                                      0.556444
# 530                                      1.578177
# 531                                     -0.582212
# 532                                     -0.515655
# 533                                     -0.490472
#
#      attention_mcelroy_harmonized_all_samples  cubids_acquisition_group
# 0                                   -1.842178                         1
# 1                                    0.190706                         1
# 2                                   -0.432662                         1
# 3                                    0.111167                         1
# 4                                   -0.782266                         1
# ..                                        ...                       ...
# 529                                  0.024228                         1
# 530                                 -0.373470                         1
# 531                                  1.333857                         1
# 532                                  1.509584                       114
# 533                                  0.018679                         1
#
# [1601 rows x 19 columns]

# %%
# First load in surface area data for each participant:
print("Loading data...")     

# We will put the rows in this dictionary of lists as we build the dataframe:
all_vars = {
    'participant_id': [],
    'ba1_surface_area': [],
    'p_factor': []}

# We'll display a progress bar `prog` as we go also:
from ipywidgets import IntProgress
prog = IntProgress(min=0, max=len(all_data))
display(prog)

# Okay, loop through each row of the `all_data` dataframe, which contains both
# training and test subjects, load their BA1 data, and store it in the
# all_vars dictionary.
for (ii, row) in all_data.iterrows():
    # Extract the participant ID and p_factor (which will be NaN for test
    # participants).
    participant_id = row['participant_id']
    p_factor = row['p_factor']
    # Load the surface area for this participant:
    try:
        surf_area = load_data_of_intrest(participant_id,structs,measures)
    except FileNotFoundError:
        # Some subjects are just missing the file, so we code them as NaN.
        surf_area = np.nan
    # Append the participant ID and their surface area to our dataset:
    all_vars['participant_id'].append(participant_id)
    all_vars['ba1_surface_area'].append(surf_area)
    all_vars['p_factor'].append(p_factor)
    # Increment the progress bar counter:
    prog.value += 1

# Convert train_vars into a dataframe.
all_vars = pd.DataFrame(all_vars)

# Extract the training and test subjects into separate dataframes; the test
# participants can be identified as those having NaN values for their
# p_factor column.
train_vars = all_vars[~np.isnan(all_vars['p_factor'])]
test_vars = all_vars[np.isnan(all_vars['p_factor'])]

# Display the finished dataframe.
all_vars
# Out:
# Loading data...
# IntProgress(value=0, max=1601)
#       participant_id                                   ba1_surface_area  \
# 0         1000393599  [1121, 3493, 1002, 2545, 1415, 4181, 1153, 398...
# 1         1001970838  [884, 2497, 935, 2385, 1174, 3343, 949, 2737, ...
# 2         1007995238  [1117, 3358, 978, 2626, 1291, 3778, 1145, 3497...
# 3         1011497669  [1027, 3196, 1131, 3384, 1351, 3958, 1037, 353...
# 4         1017092387  [1048, 3148, 1146, 2853, 1467, 4180, 1097, 355...
# ...              ...                                                ...
# 1596       969649154  [1173, 3497, 1131, 3007, 1412, 3933, 1271, 409...
# 1597       970890500  [740, 2474, 752, 2185, 977, 2860, 709, 2542, 1...
# 1598       975856179  [1205, 3815, 1138, 3525, 1532, 4692, 1251, 424...
# 1599       984757368  [1119, 3468, 987, 2799, 1205, 3520, 1388, 3970...
# 1600       987544292  [1138, 3553, 955, 2398, 1264, 3666, 1100, 3295...
#
#       p_factor
# 0     0.589907
# 1    -0.659061
# 2    -1.608375
# 3    -1.233807
# 4    -0.923100
# ...        ...
# 1596       NaN
# 1597       NaN
# 1598       NaN
# 1599       NaN
# 1600       NaN
#
# [1601 rows x 3 columns]

# %%
all_vars.to_csv("/home/jovyan/Projects/Neurohack_Group8_Miniproject/flattened_data/all.csv")

# %%
all_vars[all_vars['ba1_surface_area'].apply(lambda x: isinstance(x, list))]
# Out:
#       participant_id                                   ba1_surface_area  \
# 0         1000393599  [1121, 3493, 1002, 2545, 1415, 4181, 1153, 398...
# 1         1001970838  [884, 2497, 935, 2385, 1174, 3343, 949, 2737, ...
# 2         1007995238  [1117, 3358, 978, 2626, 1291, 3778, 1145, 3497...
# 3         1011497669  [1027, 3196, 1131, 3384, 1351, 3958, 1037, 353...
# 4         1017092387  [1048, 3148, 1146, 2853, 1467, 4180, 1097, 355...
# ...              ...                                                ...
# 1596       969649154  [1173, 3497, 1131, 3007, 1412, 3933, 1271, 409...
# 1597       970890500  [740, 2474, 752, 2185, 977, 2860, 709, 2542, 1...
# 1598       975856179  [1205, 3815, 1138, 3525, 1532, 4692, 1251, 424...
# 1599       984757368  [1119, 3468, 987, 2799, 1205, 3520, 1388, 3970...
# 1600       987544292  [1138, 3553, 955, 2398, 1264, 3666, 1100, 3295...
#
#       p_factor
# 0     0.589907
# 1    -0.659061
# 2    -1.608375
# 3    -1.233807
# 4    -0.923100
# ...        ...
# 1596       NaN
# 1597       NaN
# 1598       NaN
# 1599       NaN
# 1600       NaN
#
# [1592 rows x 3 columns]

# %%
# all_good_vars = all_vars[all_vars['ba1_surface_area'].apply(lambda x: isinstance(x, list))]
# #all_good_vars.set_index('participant_id')
# print(all_good_vars.shape)

# expanded = pd.DataFrame(all_good_vars['ba1_surface_area'].tolist(), columns=names)
# print(expanded.shape)
# expanded_data = pd.concat([all_good_vars.drop(columns=['ba1_surface_area']), expanded], axis=1)
# print(expanded_data.shape)

# expanded_data
# Out:
# (1592, 3)
# (1592, 20)
# (1601, 22)
#       participant_id  p_factor  \
# 0       1.000394e+09  0.589907
# 1       1.001971e+09 -0.659061
# 2       1.007995e+09 -1.608375
# 3       1.011498e+09 -1.233807
# 4       1.017092e+09 -0.923100
# ...              ...       ...
# 334              NaN       NaN
# 874              NaN       NaN
# 923              NaN       NaN
# 1509             NaN       NaN
# 1538             NaN       NaN
#
#       aparc.DKTatlas__lh__caudalanteriorcingulateSurfArea  \
# 0                                                1121.0
# 1                                                 884.0
# 2                                                1117.0
# 3                                                1027.0
# 4                                                1048.0
# ...                                                 ...
# 334                                              1063.0
# 874                                              1190.0
# 923                                              1083.0
# 1509                                             1129.0
# 1538                                             1110.0
#
#       aparc.DKTatlas__lh__isthmuscingulateSurfArea  \
# 0                                           3493.0
# 1                                           2497.0
# 2                                           3358.0
# 3                                           3196.0
# 4                                           3148.0
# ...                                            ...
# 334                                         2900.0
# 874                                         3755.0
# 923                                         3845.0
# 1509                                        3609.0
# 1538                                        3037.0
#
#       aparc.DKTatlas__lh__posteriorcingulateSurfArea  \
# 0                                             1002.0
# 1                                              935.0
# 2                                              978.0
# 3                                             1131.0
# 4                                             1146.0
# ...                                              ...
# 334                                           1453.0
# 874                                            861.0
# 923                                            996.0
# 1509                                          1079.0
# 1538                                          1177.0
#
#       aparc.DKTatlas__lh__rostralanteriorcingulateSurfArea  \
# 0                                                2545.0
# 1                                                2385.0
# 2                                                2626.0
# 3                                                3384.0
# 4                                                2853.0
# ...                                                 ...
# 334                                              4516.0
# 874                                              2222.0
# 923                                              2815.0
# 1509                                             3384.0
# 1538                                             2549.0
#
#       aparc.DKTatlas__lh__insulaSurfArea  \
# 0                                 1415.0
# 1                                 1174.0
# 2                                 1291.0
# 3                                 1351.0
# 4                                 1467.0
# ...                                  ...
# 334                               1405.0
# 874                               1193.0
# 923                               1265.0
# 1509                              1329.0
# 1538                              1366.0
#
#       aparc.DKTatlas__rh__caudalanteriorcingulateSurfArea  \
# 0                                                4181.0
# 1                                                3343.0
# 2                                                3778.0
# 3                                                3958.0
# 4                                                4180.0
# ...                                                 ...
# 334                                              3764.0
# 874                                              3353.0
# 923                                              3727.0
# 1509                                             4220.0
# 1538                                             3480.0
#
#       aparc.DKTatlas__rh__isthmuscingulateSurfArea  \
# 0                                           1153.0
# 1                                            949.0
# 2                                           1145.0
# 3                                           1037.0
# 4                                           1097.0
# ...                                            ...
# 334                                         1262.0
# 874                                         1291.0
# 923                                         1209.0
# 1509                                        1226.0
# 1538                                        1141.0
#
#       aparc.DKTatlas__rh__posteriorcingulateSurfArea  ...  \
# 0                                             3980.0  ...
# 1                                             2737.0  ...
# 2                                             3497.0  ...
# 3                                             3538.0  ...
# 4                                             3550.0  ...
# ...                                              ...  ...
# 334                                           3679.0  ...
# 874                                           4262.0  ...
# 923                                           3806.0  ...
# 1509                                          4138.0  ...
# 1538                                          3690.0  ...
#
#       aparc.DKTatlas__lh__caudalanteriorcingulateGrayVol  \
# 0                                                 607.0
# 1                                                 710.0
# 2                                                 677.0
# 3                                                 927.0
# 4                                                 757.0
# ...                                                 ...
# 334                                               608.0
# 874                                               853.0
# 923                                               638.0
# 1509                                              893.0
# 1538                                             1027.0
#
#       aparc.DKTatlas__lh__isthmuscingulateGrayVol  \
# 0                                          2092.0
# 1                                          1892.0
# 2                                          2119.0
# 3                                          2710.0
# 4                                          2742.0
# ...                                           ...
# 334                                        1659.0
# 874                                        2619.0
# 923                                        2155.0
# 1509                                       2967.0
# 1538                                       3204.0
#
#       aparc.DKTatlas__lh__posteriorcingulateGrayVol  \
# 0                                             945.0
# 1                                             829.0
# 2                                             824.0
# 3                                             926.0
# 4                                             905.0
# ...                                             ...
# 334                                          1212.0
# 874                                           912.0
# 923                                           808.0
# 1509                                          933.0
# 1538                                         1248.0
#
#       aparc.DKTatlas__lh__rostralanteriorcingulateGrayVol  \
# 0                                                2586.0
# 1                                                2187.0
# 2                                                2325.0
# 3                                                2629.0
# 4                                                2533.0
# ...                                                 ...
# 334                                              3622.0
# 874                                              2471.0
# 923                                              2451.0
# 1509                                             2904.0
# 1538                                             3109.0
#
#       aparc.DKTatlas__lh__insulaGrayVol  \
# 0                                1363.0
# 1                                1150.0
# 2                                1326.0
# 3                                1522.0
# 4                                1254.0
# ...                                 ...
# 334                              1366.0
# 874                              1386.0
# 923                              1083.0
# 1509                             1439.0
# 1538                             1381.0
#
#       aparc.DKTatlas__rh__caudalanteriorcingulateGrayVol  \
# 0                                                4428.0
# 1                                                3410.0
# 2                                                4015.0
# 3                                                4383.0
# 4                                                3735.0
# ...                                                 ...
# 334                                              4206.0
# 874                                              4121.0
# 923                                              3462.0
# 1509                                             4313.0
# 1538                                             3802.0
#
#       aparc.DKTatlas__rh__isthmuscingulateGrayVol  \
# 0                                           718.0
# 1                                           849.0
# 2                                           886.0
# 3                                           927.0
# 4                                           686.0
# ...                                           ...
# 334                                         635.0
# 874                                         979.0
# 923                                         795.0
# 1509                                        768.0
# 1538                                        894.0
#
#       aparc.DKTatlas__rh__posteriorcingulateGrayVol  \
# 0                                            2239.0
# 1                                            2656.0
# 2                                            2765.0
# 3                                            2976.0
# 4                                            2560.0
# ...                                             ...
# 334                                          1952.0
# 874                                          3110.0
# 923                                          2462.0
# 1509                                         2756.0
# 1538                                         2963.0
#
#       aparc.DKTatlas__rh__rostralanteriorcingulateGrayVol  \
# 0                                                1976.0
# 1                                                2214.0
# 2                                                1843.0
# 3                                                2014.0
# 4                                                1932.0
# ...                                                 ...
# 334                                              2443.0
# 874                                              2145.0
# 923                                              2220.0
# 1509                                             2066.0
# 1538                                             2082.0
#
#       aparc.DKTatlas__rh__insulaGrayVol
# 0                                6407.0
# 1                                7093.0
# 2                                6499.0
# 3                                7053.0
# 4                                6429.0
# ...                                 ...
# 334                              7617.0
# 874                              6812.0
# 923                              8157.0
# 1509                             6672.0
# 1538                             6593.0
#
# [1601 rows x 22 columns]

# %%
# Keep only rows where 'ba1_surface_area' is a list
all_good_vars = all_vars[all_vars['ba1_surface_area'].apply(lambda x: isinstance(x, list))].copy()

# (Optional) Reset index or set participant_id as index if needed
# all_good_vars = all_good_vars.set_index('participant_id')  # Uncomment if desired

# Show shape of filtered dataframe
print("Filtered shape:", all_good_vars.shape)

# Expand list column into separate columns
expanded = pd.DataFrame(all_good_vars['ba1_surface_area'].tolist(), columns=names)

print("Expanded shape:", expanded.shape)

# Reset index before combining
all_good_vars = all_good_vars.reset_index(drop=True)
expanded = expanded.reset_index(drop=True)

# Now concatenate
expanded_data = pd.concat([all_good_vars.drop(columns=['ba1_surface_area']), expanded], axis=1)
print("Final shape:", expanded_data.shape)

# Save it
expanded_data.to_csv('/home/jovyan/Projects/Neurohack_Group8_Miniproject/flattened_data/all_cleaned.csv')
# Out:
# Filtered shape: (1592, 3)
# Expanded shape: (1592, 20)
# Final shape: (1592, 22)

# %%
all_vars['ba1_surface_area'].apply(type).value_counts()
# Out:
# ba1_surface_area
# <class 'list'>     1592
# <class 'float'>       9
# Name: count, dtype: int64
